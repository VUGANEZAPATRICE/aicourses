# %%
from google.colab import drive
drive.mount("/content/Drive")
# Out:
# Mounted at /content/Drive

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Scraping only jobs from jobinrwanda

# %%
content_jobs = requests.get("https://www.jobinrwanda.com/jobs/all")
soup =  BeautifulSoup(content_jobs.content, "html.parser")

# %%
# function to loop through all jobs from main page
def parsing_job_in_rwanda(soup):
  main_dict = {}
  adverts_jobs = soup.find_all("div", class_="card-body p-2")
  job_title_list =[]
  company_name_list= []
  job_link_list=[]
  #company_profile = []
  company_link_list=[]
  #job_description = []
  category_list =[]
  experience_list = []
  published_date_list =[]
  deadline_list =[]

  for index, advert_job in enumerate(adverts_jobs):
    title = adverts_jobs[index].find("span", class_="field field--name-title field--type-string field--label-hidden").text
    title_link = "https://www.jobinrwanda.com"+adverts_jobs[index].find('a')['href']
    company_link = "https://www.jobinrwanda.com"+ adverts_jobs[index].find("p",class_="card-text").find("a")["href"]
    company_name = adverts_jobs[index].find("p",class_="card-text").find("a").text
    published_date = adverts_jobs[index].find("p", class_="card-text").text.split("\n")[2].strip().split("|")[0]
    deadline = adverts_jobs[index].find('time').text
    experience = adverts_jobs[index].find("p",class_="card-text").text.split("\n")[5].strip()
    #category = adverts_jobs[index].find("p", class_="card-text").find("span", class_="badge badge-primary").text
    category = adverts_jobs[index].find("p",class_="card-text").find("span",class_="badge badge-primary").getText()
               #job_posts[0].find("p",class_="card-text").find("span",class_="badge badge-primary").text
    job_title_list.append(title)
    company_name_list.append(company_name)
    job_link_list.append(title_link)
    company_link_list.append(company_link)
    category_list.append(category)
    experience_list.append(experience)
    published_date_list.append(published_date)
    deadline_list.append(deadline)

  main_dict["job_title"] = job_title_list
  main_dict["company_name"] = company_name_list
  main_dict["job_link"] = job_link_list
  main_dict["company_link"] = company_link_list
  main_dict["job_category"] = category_list
  main_dict["job_experience"] = experience_list
  main_dict["published_date"] = published_date_list
  main_dict["job_deadline"] = deadline_list

  return main_dict

# %%
main_dict_here =parsing_job_in_rwanda(soup)
main_dict_here
# Out:
# {'job_title': ['Operations Manager',
#   'Account Manager- Credit',
#   'Legal Manager',
#   'District Coordinator/Junior District Manager',
#   'Radio Sales Executives',
#   'Radio Presenter',
#   'Driver',
#   'Procurement and Logistics Officer',
#   'Product Manager',
#   'Aftercare/ Vehicle Maintenance Manager',
#   'Finance Officer',
#   'Communications Officer',
#   'Lecturer, Communication and Writing',
#   'Research Associate (RA)',
#   'Office Assistant',
#   'Head of Field Office(Huye)',
#   'Human Resources Assistant',
#   'Rwanda Impact Specialist',
#   'Operations Support Manager (Africa)',
#   'Accounting Supervisor',
#   'Accounting Manager',
#   'Business Development Officer',
#   'Regional Grants Officer',
#   'Global Head of Corporate Communications',
#   'Public Relations Officer',
#   'Grants Manager',
#   'HVAC Lead Technician',
#   'Maintenance Mechanic (Appliance Repair)',
#   'Camp Administrator',
#   'Rwanda Program Officer ',
#   'Sales Representative',
#   'Sales Manager',
#   'Aquaculture Technician',
#   'Health Systems Strengthening (HSS) Manager',
#   'Development Manager',
#   'Retail Partnerships Lead',
#   'Project Officer',
#   'Administration & Finance Intern',
#   'Loan Officers\xa0',
#   'Project Manager',
#   'Training Manager ',
#   'IT and MIS Director',
#   'Learning Design Specialist, Rwanda',
#   'Technical Advisor ',
#   'Front Desk Officer',
#   'Global Remote Sensing Manager',
#   'Laborer',
#   'Migration Health Physician',
#   'Migration Health Nurse',
#   'Global HR Support Specialist',
#   'Rwanda Procurement Specialist',
#   'Security Officer',
#   'Security Supervisor',
#   'Instructional Technology Assistant\xa0',
#   'Associate Professor\xa0and\xa0Head of Human Anatomy\xa0',
#   'Rwanda Potato Seed Store Manager',
#   'Agronomist Technician, G-2(C)',
#   'Dental Doctors /Dental Surgeon',
#   'Head of Rehabilitation Department',
#   'Assistant in the Press Department, Administration and Consular Section',
#   'Rwanda Warehouse Manager',
#   'CSAT Officer – Rwanda',
#   'SPM Officer',
#   'Rwanda Communications Associate',
#   'Strategic Advisor – Targeted Skills Development',
#   'Strategic Advisor– E-Commerce',
#   'Sales Representatives Needed at All City Rwanda Ltd',
#   'Store Keeper',
#   'Rwanda Market Access and SRF MEL Associate',
#   'Rwanda Field Integration Coordinator',
#   'Rwanda Electrical Hub Operator',
#   'Rwanda Tree Lead',
#   'Rwanda Potato Seed Venture \ufeff\ufeffLead',
#   'IT Operations Senior Manager',
#   'Rwanda Seed Innovation Centre Lead',
#   'Senior Business Analyst'],
#  'company_name': ['GardaWorld ',
#   'Yellow',
#   'COPEDU PLC ',
#   'EarthEnable Rwanda',
#   'ROYAL RADIO LTD',
#   'ROYAL RADIO LTD',
#   'Water For People-',
#   'Water For People-',
#   'Ampersand Rwanda Ltd',
#   'Ampersand Rwanda Ltd',
#   'IntraHealth',
#   'Rwanda Women’s Network (RWN)',
#   'University of Global Health Equity (UGHE)',
#   'IPA Rwanda',
#   'Inkomoko Entrepreneur Development',
#   'World Food Programme (WFP)',
#   'Loveway Rwanda Co. Ltd',
#   'One Acre Fund',
#   'Practical Action ',
#   'ExCraft Ltd',
#   'ExCraft Ltd',
#   'Career Options Africa Ltd',
#   'Wildlife Conservation Society (WCS Rwanda)',
#   'One Acre Fund',
#   'Business Professionals Network (BPN) -  Rwanda',
#   'World Vision International Rwanda ',
#   'American Embassy Kigali  Mission Rwanda',
#   'American Embassy Kigali  Mission Rwanda',
#   'Rwandamotor Ltd',
#   'Global Health Corps (GHC)',
#   'Global Electric Vehicle Ltd',
#   'Global Electric Vehicle Ltd',
#   'Kivu Choice',
#   'The Fred Hollows Foundation ',
#   'Business Professionals Network (BPN) -  Rwanda',
#   'One Acre Fund',
#   'PRO-FEMMES/TWESE HAMWE (PFTH) ',
#   'HOPE International',
#   'ASA International (Rwanda) Plc',
#   'Plan International Rwanda',
#   'Premier Bet',
#   'CHANCEN International Rwanda',
#   'Educate',
#   'Spark MicroGrants',
#   'Kigali International Arbitration Centre (KIAC) ',
#   'One Acre Fund',
#   'American Embassy Kigali  Mission Rwanda',
#   'International Organization for Migration (IOM)',
#   'International Organization for Migration (IOM)',
#   'One Acre Fund',
#   'One Acre Fund',
#   'Kivu Choice Ltd',
#   'Kivu Choice Ltd',
#   'University of Global Health Equity (UGHE)',
#   'University of Global Health Equity (UGHE)',
#   'One Acre Fund',
#   'University of Rwanda Holdings Group Limited (UR - HG Ltd)',
#   'University of Rwanda Holdings Group Limited (UR - HG Ltd)',
#   'Gahini District Hospital',
#   'Embassy of the Federal Republic of Germany',
#   'One Acre Fund',
#   'C Quest Capital',
#   'BRAC',
#   'One Acre Fund',
#   'Tony Blair Institute for Global Change',
#   'Tony Blair Institute for Global Change',
#   'ALL CITY GROUP',
#   'ExCraft Ltd',
#   'One Acre Fund',
#   'One Acre Fund',
#   'One Acre Fund',
#   'One Acre Fund',
#   'One Acre Fund',
#   'One Acre Fund',
#   'One Acre Fund',
#   'One Acre Fund'],
#  'job_link': ['https://www.jobinrwanda.com/job/operations-manager-6',
#   'https://www.jobinrwanda.com/job/account-manager-credit',
#   'https://www.jobinrwanda.com/job/legal-manager',
#   'https://www.jobinrwanda.com/job/district-coordinatorjunior-district-manager',
#   'https://www.jobinrwanda.com/job/radio-sales-executives',
#   'https://www.jobinrwanda.com/job/radio-presenter-0',
#   'https://www.jobinrwanda.com/job/driver-16',
#   'https://www.jobinrwanda.com/job/procurement-and-logistics-officer',
#   'https://www.jobinrwanda.com/job/product-manager-1',
#   'https://www.jobinrwanda.com/job/aftercare-vehicle-maintenance-manager',
#   'https://www.jobinrwanda.com/job/finance-officer-9',
#   'https://www.jobinrwanda.com/job/communications-officer-8',
#   'https://www.jobinrwanda.com/job/lecturer-communication-and-writing',
#   'https://www.jobinrwanda.com/job/research-associate-ra-0',
#   'https://www.jobinrwanda.com/job/office-assistant-0',
#   'https://www.jobinrwanda.com/job/head-field-officehuye',
#   'https://www.jobinrwanda.com/job/human-resources-assistant-0',
#   'https://www.jobinrwanda.com/job/rwanda-impact-specialist',
#   'https://www.jobinrwanda.com/job/operations-support-manager-africa',
#   'https://www.jobinrwanda.com/job/accounting-supervisor',
#   'https://www.jobinrwanda.com/job/accounting-manager-1',
#   'https://www.jobinrwanda.com/job/business-development-officer',
#   'https://www.jobinrwanda.com/job/regional-grants-officer-central-africa',
#   'https://www.jobinrwanda.com/job/global-head-corporate-communications',
#   'https://www.jobinrwanda.com/index.php/job/public-relations-officer',
#   'https://www.jobinrwanda.com/job/grants-manager-2',
#   'https://www.jobinrwanda.com/job/hvac-lead-technician',
#   'https://www.jobinrwanda.com/job/maintenance-mechanic-appliance-repair-0',
#   'https://www.jobinrwanda.com/job/camp-administrator',
#   'https://www.jobinrwanda.com/job/rwanda-program-officer',
#   'https://www.jobinrwanda.com/job/sales-representative-0',
#   'https://www.jobinrwanda.com/job/sales-manager-5',
#   'https://www.jobinrwanda.com/job/aquaculture-technician',
#   'https://www.jobinrwanda.com/job/health-systems-strengthening-hss-manager',
#   'https://www.jobinrwanda.com/index.php/job/development-manager',
#   'https://www.jobinrwanda.com/job/retail-partnerships-lead',
#   'https://www.jobinrwanda.com/job/project-officer-7',
#   'https://www.jobinrwanda.com/job/administration-finance-intern',
#   'https://www.jobinrwanda.com/job/loan-officers-3',
#   'https://www.jobinrwanda.com/job/project-manager-14',
#   'https://www.jobinrwanda.com/job/training-manager-0',
#   'https://www.jobinrwanda.com/job/it-and-mis-director',
#   'https://www.jobinrwanda.com/job/learning-design-specialist-rwanda',
#   'https://www.jobinrwanda.com/job/technical-advisor-2',
#   'https://www.jobinrwanda.com/job/front-desk-officer-0',
#   'https://www.jobinrwanda.com/job/global-remote-sensing-manager',
#   'https://www.jobinrwanda.com/job/laborer',
#   'https://www.jobinrwanda.com/job/migration-health-physician',
#   'https://www.jobinrwanda.com/index.php/job/migration-health-nurse',
#   'https://www.jobinrwanda.com/job/global-hr-support-specialist',
#   'https://www.jobinrwanda.com/job/rwanda-procurement-specialist-0',
#   'https://www.jobinrwanda.com/job/security-officer',
#   'https://www.jobinrwanda.com/job/security-supervisor',
#   'https://www.jobinrwanda.com/job/instructional-technology-assistant',
#   'https://www.jobinrwanda.com/job/associate-professor-and-head-human-anatomy',
#   'https://www.jobinrwanda.com/job/rwanda-potato-seed-store-manager',
#   'https://www.jobinrwanda.com/job/agronomist-technician-g-2c',
#   'https://www.jobinrwanda.com/job/dental-doctors-dental-surgeon',
#   'https://www.jobinrwanda.com/job/head-rehabilitation-department',
#   'https://www.jobinrwanda.com/job/assistant-press-department-administration-and-consular-section',
#   'https://www.jobinrwanda.com/job/rwanda-warehouse-manager',
#   'https://www.jobinrwanda.com/job/csat-officer-rwanda',
#   'https://www.jobinrwanda.com/job/spm-officer',
#   'https://www.jobinrwanda.com/index.php/job/rwanda-communications-associate',
#   'https://www.jobinrwanda.com/job/strategic-advisor-targeted-skills-development',
#   'https://www.jobinrwanda.com/job/strategic-advisor-e-commerce',
#   'https://www.jobinrwanda.com/job/50-sales-representatives-needed-all-city-rwanda-ltd-1',
#   'https://www.jobinrwanda.com/job/store-keeper-1',
#   'https://www.jobinrwanda.com/index.php/job/rwanda-market-access-and-srf-mel-associate',
#   'https://www.jobinrwanda.com/job/rwanda-field-integration-coordinator',
#   'https://www.jobinrwanda.com/job/rwanda-electrical-hub-operator',
#   'https://www.jobinrwanda.com/job/rwanda-tree-lead',
#   'https://www.jobinrwanda.com/index.php/job/rwanda-potato-seed-venture-lead',
#   'https://www.jobinrwanda.com/job/it-operations-senior-manager',
#   'https://www.jobinrwanda.com/job/rwanda-seed-innovation-centre-lead',
#   'https://www.jobinrwanda.com/job/senior-business-analyst'],
#  'company_link': ['https://www.jobinrwanda.com/employer/gardaworld',
#   'https://www.jobinrwanda.com/employer/yellow',
#   'https://www.jobinrwanda.com/employer/copedu-plc',
#   'https://www.jobinrwanda.com/employer/earthenable-rwanda',
#   'https://www.jobinrwanda.com/employer/royal-radio-ltd',
#   'https://www.jobinrwanda.com/employer/royal-radio-ltd',
#   'https://www.jobinrwanda.com/employer/water-people',
#   'https://www.jobinrwanda.com/employer/water-people',
#   'https://www.jobinrwanda.com/employer/ampersand-rwanda-ltd',
#   'https://www.jobinrwanda.com/employer/ampersand-rwanda-ltd',
#   'https://www.jobinrwanda.com/employer/intrahealth',
#   'https://www.jobinrwanda.com/employer/rwanda-womens-network-rwn',
#   'https://www.jobinrwanda.com/employer/university-global-health-equity-ughe',
#   'https://www.jobinrwanda.com/employer/ipa-rwanda',
#   'https://www.jobinrwanda.com/employer/inkomoko-entrepreneur-development',
#   'https://www.jobinrwanda.com/employer/world-food-programme-wfp',
#   'https://www.jobinrwanda.com/employer/loveway-rwanda-co-ltd',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/practical-action',
#   'https://www.jobinrwanda.com/employer/excraft-ltd',
#   'https://www.jobinrwanda.com/employer/excraft-ltd',
#   'https://www.jobinrwanda.com/employer/career-options-africa-ltd',
#   'https://www.jobinrwanda.com/employer/wildlife-conservation-society-wcs-rwanda',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/index.php/employer/business-professionals-network-bpn-rwanda',
#   'https://www.jobinrwanda.com/employer/world-vision-international-rwanda-0',
#   'https://www.jobinrwanda.com/employer/american-embassy-kigali-mission-rwanda',
#   'https://www.jobinrwanda.com/employer/american-embassy-kigali-mission-rwanda',
#   'https://www.jobinrwanda.com/employer/rwandamotor-ltd',
#   'https://www.jobinrwanda.com/employer/global-health-corps-ghc',
#   'https://www.jobinrwanda.com/employer/global-electric-vehicle-ltd',
#   'https://www.jobinrwanda.com/employer/global-electric-vehicle-ltd',
#   'https://www.jobinrwanda.com/employer/kivu-choice',
#   'https://www.jobinrwanda.com/employer/fred-hollows-foundation',
#   'https://www.jobinrwanda.com/index.php/employer/business-professionals-network-bpn-rwanda',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/pro-femmestwese-hamwe-pfth',
#   'https://www.jobinrwanda.com/employer/hope-international-0',
#   'https://www.jobinrwanda.com/employer/asa-microfinance-rwanda-plc',
#   'https://www.jobinrwanda.com/employer/plan-international-rwanda',
#   'https://www.jobinrwanda.com/employer/premier-bet',
#   'https://www.jobinrwanda.com/employer/chancen-international',
#   'https://www.jobinrwanda.com/employer/educate',
#   'https://www.jobinrwanda.com/employer/spark-microgrants',
#   'https://www.jobinrwanda.com/employer/kigali-international-arbitration-centre-kiac',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/american-embassy-kigali-mission-rwanda',
#   'https://www.jobinrwanda.com/employer/international-organization-migration-iom-0',
#   'https://www.jobinrwanda.com/index.php/employer/international-organization-migration-iom-0',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/kivu-choice-ltd',
#   'https://www.jobinrwanda.com/employer/kivu-choice-ltd',
#   'https://www.jobinrwanda.com/employer/university-global-health-equity-ughe',
#   'https://www.jobinrwanda.com/employer/university-global-health-equity-ughe',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/university-rwanda-holdings-group-limited-ur-hg-ltd',
#   'https://www.jobinrwanda.com/employer/university-rwanda-holdings-group-limited-ur-hg-ltd',
#   'https://www.jobinrwanda.com/employer/gahini-district-hospital',
#   'https://www.jobinrwanda.com/employer/embassy-federal-republic-germany',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/c-quest-capital',
#   'https://www.jobinrwanda.com/employer/brac',
#   'https://www.jobinrwanda.com/index.php/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/tony-blair-institute-global-change-0',
#   'https://www.jobinrwanda.com/employer/tony-blair-institute-global-change-0',
#   'https://www.jobinrwanda.com/employer/all-city-group',
#   'https://www.jobinrwanda.com/employer/excraft-ltd',
#   'https://www.jobinrwanda.com/index.php/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/index.php/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/one-acre-fund'],
#  'job_category': ['Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job',
#   'Job'],
#  'job_experience': ['Senior (5+ years of experience)',
#   'Not specified',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Not specified',
#   '',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   '',
#   'Entry level (1 to 3 years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Senior (5+ years of experience)',
#   'Not specified',
#   'Not specified',
#   'Not specified',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Not specified',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Mid career (3 to 5 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Senior (5+ years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Senior (5+ years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'No experience',
#   '',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Not specified',
#   'Not specified',
#   'Mid career (3 to 5 years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   '',
#   '',
#   '',
#   'Senior (5+ years of experience)',
#   'Not specified',
#   '',
#   ''],
#  'published_date': ['Published on 03-11-2022 ',
#   'Published on 27-10-2022 ',
#   'Published on 12-11-2022 ',
#   'Published on 11-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 10-11-2022 ',
#   'Published on 09-11-2022 ',
#   'Published on 09-11-2022 ',
#   'Published on 09-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 08-11-2022 ',
#   'Published on 07-11-2022 ',
#   'Published on 04-11-2022 ',
#   'Published on 04-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 04-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 03-11-2022 ',
#   'Published on 02-11-2022 ',
#   'Published on 02-11-2022 ',
#   'Published on 01-11-2022 ',
#   'Published on 01-11-2022 ',
#   'Published on 01-11-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 31-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 28-10-2022 ',
#   'Published on 27-10-2022 ',
#   'Published on 27-10-2022 ',
#   'Published on 27-10-2022 ',
#   'Published on 25-10-2022 ',
#   'Published on 21-10-2022 ',
#   'Published on 21-10-2022 ',
#   'Published on 21-10-2022 ',
#   'Published on 21-10-2022 ',
#   'Published on 20-10-2022 ',
#   'Published on 20-10-2022 ',
#   'Published on 19-10-2022 ',
#   'Published on 14-10-2022 ',
#   'Published on 13-10-2022 ',
#   'Published on 12-10-2022 ',
#   'Published on 12-10-2022 ',
#   'Published on 15-09-2022 ',
#   'Published on 14-09-2022 ',
#   'Published on 07-09-2022 ',
#   'Published on 01-09-2022 ',
#   'Published on 22-08-2022 '],
#  'job_deadline': ['14-11-2022',
#   '27-11-2022',
#   '18-11-2022',
#   '30-11-2022',
#   '15-11-2022',
#   '15-11-2022',
#   '20-11-2022',
#   '20-11-2022',
#   '10-01-2023',
#   '10-12-2022',
#   '18-11-2022',
#   '18-11-2022',
#   '09-12-2022',
#   '11-12-2022',
#   '17-11-2022',
#   '23-11-2022',
#   '22-11-2022',
#   '15-01-2023',
#   '30-11-2022',
#   '08-12-2022',
#   '08-12-2022',
#   '21-11-2022',
#   '30-11-2022',
#   '30-01-2023',
#   '20-11-2022',
#   '20-11-2022',
#   '17-11-2022',
#   '17-11-2022',
#   '03-12-2022',
#   '03-12-2022',
#   '23-11-2022',
#   '23-11-2022',
#   '03-12-2022',
#   '18-11-2022',
#   '19-11-2022',
#   '30-01-2023',
#   '14-11-2022',
#   '18-11-2022',
#   '18-11-2022',
#   '21-11-2022',
#   '01-12-2022',
#   '18-11-2022',
#   '28-11-2022',
#   '30-11-2022',
#   '15-11-2022',
#   '25-01-2023',
#   '14-11-2022',
#   '13-11-2022',
#   '13-11-2022',
#   '28-12-2022',
#   '30-11-2022',
#   '28-11-2022',
#   '28-11-2022',
#   '28-11-2022',
#   '28-11-2022',
#   '26-11-2022',
#   '18-11-2022',
#   '18-11-2022',
#   '14-11-2022',
#   '18-11-2022',
#   '19-11-2022',
#   '21-11-2022',
#   '15-11-2022',
#   '03-01-2023',
#   '18-11-2022',
#   '18-11-2022',
#   '19-11-2022',
#   '14-11-2022',
#   '10-01-2023',
#   '30-11-2022',
#   '19-11-2022',
#   '20-11-2022',
#   '28-11-2022',
#   '06-12-2022',
#   '29-11-2022',
#   '17-11-2022']}

# %%
# looping through job description

#employer_page[0].text
company_profile = []
company_description = []
job_summary= []

for link in main_dict_here["job_link"]:
  company_page = requests.get(link).content
  #job_description_raw_content = requests.get('https://www.jobinrwanda.com/job/global-remote-sensing-manager').content

  soup_company_page = BeautifulSoup(company_page,'html.parser')
  employer_page = soup_company_page.find_all('div', class_='employer-description') #Employer Description
  describe = soup_company_page.find_all('div', class_="clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item") #Employer Description
  company_prof = ''
  company_desc = ''
   #Construct an empty string to hold the paragraph
  for index,emp_page in enumerate(employer_page):
    for textt in employer_page[0].text.split('\n'):
      company_prof += textt +'\n'
    description1 = ''
    for paragraph in describe:
      description1 += paragraph.getText() #Adding each paragraph we find in the job description.

    for textt in description1.split('\n'):
      company_desc += textt +'\n'

  #summary_content =requests.get("https://www.jobinrwanda.com/job/customer-service-officer-1").content
  #s_soup = BeautifulSoup(summary_content,'html.parser')
  soup_company_page=BeautifulSoup(company_page,'html.parser')
  #s_soup1 = soup_company_page.find("div",class_="card-header bg-primary").getText().strip()
  #print(s_soup1)
  s_soup2 = soup_company_page.find_all("div",class_="card border-primary sidebar-block")[0].find_all('ul', class_="list-group list-group-flush")[0].find_all('li')[:7]
  summary1=''
  for ss in s_soup2:
    summary1 +=ss.getText().strip()

  
  company_description.append(company_desc)
  company_profile.append(company_prof)
  job_summary.append(summary1)

# %%
# Adding Job description to dictionary

print(len(company_profile))
print(company_profile)
main_dict_here["Company_Profile"] = company_profile
main_dict_here["company_description"] = company_description
main_dict_here["job_summary"] = job_summary

print(main_dict_here['job_summary'])
# Out:
# 76
# ['\nGardaWorld is one of the largest privately owned integrated physical security, cash management and risk management companies in the world. Our services are important to our clients, as they rely on us to keep them and their environments safe. We offer peace of mind for our clients who operate in a complex world, by providing a wide range of industry-leading security services, delivered by experienced and knowledgeable experts. Through our comprehensive security solutions, we help protect businesses, employees, communities and assets and make the world a safer place.\n\n', '', '\nCOPEDU PLC is a microfinance institution that provides financial services such as credits and savings to its customers. COPEDU LTD was registered as a Microfinance Company in Rwanda Development Board (RDB) on February 21, 2013, with a certificate to perform microfinance services by the Central Bank of Rwanda (BNR) on 13th/03/2014.\nOn 25th/01/2019, COPEDU LTD changed its name to COPEDU PLC following the provisions of Law N ° 17/2018 of 13/04/2018 governing commercial companies. This means that COPEDU PLC is a Public Limited Company that can call on the public for investments as shares.\n\n', '\nWho we are\nAt EarthEnable, we believe that our clients deserve our very best, that morning high-fives are the best way to start the day, and that the best ideas could come from any part of the company. We celebrate each other’s wins, learn from our setbacks, and are deeply proud of the impact we make every day. We believe that a clean, dust-free floor means more than living in a healthy home. It means pride and dignity in the place our customers most treasure: their homes. Being a part of our team means more than building floors: it means building an organization and building a better future for rural families.\nWhat we do\nEarthEnable is transforming the way people live, by making homes healthier for families across rural Rwanda. 80% of Rwandans live in homes with dirt floors which are dusty, unsanitary, and fertile breeding grounds for parasites and germs. While replacing a dirt floor with concrete has significant health benefits (e.g. reducing diarrhea by 50% and parasitic infections by 80%), concrete is unaffordable for many who need it.\n\nEarthEnable addresses this pressing and ubiquitous problem by selling high-quality, earthen floors that are 80% cheaper than concrete with 90% less embedded energy. Earthen floors are already prevalent in modern homes in the United States and are composed of natural materials (gravel, clay, sand, and laterite). EarthEnable trains and hires local masons to install the floors which are sealed using a proprietary drying oil that makes them waterproof, strong, and polished. In our first 3 years of operations, EarthEnable has installed over 40,000 square meters of flooring and employed over 200 Rwandese staff (and generated jobs and income for an additional 100 masons).\n\n', '', '', '\nWater For People (WFP) is a global nonprofit working across nine countries, bringing together communities, local entrepreneurs, and governments to build and maintain water and sanitation services that will last. We have a sustainable solution to end the global water and sanitation crisis, and our employees across the world help drive this solution.\n\n', '\nWater For People (WFP) is a global nonprofit working across nine countries, bringing together communities, local entrepreneurs, and governments to build and maintain water and sanitation services that will last. We have a sustainable solution to end the global water and sanitation crisis, and our employees across the world help drive this solution.\n\n', '\nAmpersand is an energy and mobility startup based in Kigali. We’re building electric taxi motorcycles that perform better, are easier to drive, cost less to buy and operate, and take less time to refuel.\nWe want to achieve the world’s first true mass-market shift from petrol to electric power across a major vehicle fleet, achieving  ...
# ['This advert has been viewed 2297 timesLocation: \n        , RWSector:\n                                              Administration,                                              Business,                                              Management,                                              OtherEducation level\n            : BachelorDesired experience: Senior (5+ years of experience)Contract type\n          : Full-timeDeadline: Monday, 14/11/2022 23:59', 'This advert has been viewed 3876 timesLocation: Malawi, Uganda, Zambia, Rwanda\n        , RWSector:\n                                              OtherEducation level\n            : Not specifiedDesired experience: Not specifiedContract type\n          : Full-timeDeadline: Sunday, 27/11/2022 23:59', 'This advert has been viewed 128 timesLocation: \n        , RWSector:\n                                              Finance and investment,                                              Law,                                              OtherEducation level\n            : BachelorDesired experience: Mid career (3 to 5 years of experience)Contract type\n          : Full-timeDeadline: Friday, 18/11/2022 23:59', 'This advert has been viewed 1229 timesLocation: \n        , RWSector:\n                                              Management,                                              OtherEducation level\n            : BachelorDesired experience: Not specifiedContract type\n          : Full-timeDeadline: Wednesday, 30/11/2022 23:59', 'This advert has been viewed 354 timesLocation: \n        , RWSector:\n                                              Marketing and sales,                                              OtherEducation level\n            : BachelorDesired experience: Not specifiedContract type\n          : Full-timeDeadline: Tuesday, 15/11/2022 23:59', 'This advert has been viewed 463 timesLocation: \n        , RWSector:\n                                              Communications,                                              Journalism,                                              OtherEducation level\n            : BachelorDesired experience:Contract type\n          : Full-timeDeadline: Tuesday, 15/11/2022 23:59', 'This advert has been viewed 1315 timesLocation: \n        , RWSector:\n                                              OtherEducation level\n            : DiplomaDesired experience: Senior (5+ years of experience)Contract type\n          : Full-timeDeadline: Sunday, 20/11/2022 23:59', 'This advert has been viewed 901 timesLocation: \n        , RWSector:\n                                              Administration,                                              Business,                                              Other,                                              ProcurementEducation level\n            : BachelorDesired experience: Senior (5+ years of experience)Contract type\n          : Full-timeDeadline: Sunday, 20/11/2022 23:59', 'This advert has been viewed 311 timesLocation: Kigali\n        , RWSector:\n                                              Computer and IT,                                              Management,                                              Project managementEducation level\n            : BachelorDesired experience: Senior (5+ years of experience)Contract type\n          : Full-timeDeadline: Tuesday, 10/01/2023 23:59', 'This advert has been viewed 188 timesLocation: Kigali\n        , RWSector:\n                                              Management,                                              Mechanical engineering,                                              Vehicle mechanicalEducation level\n            : BachelorDesired experience: Senior (5+ years of experience)Contract type\n          : Full-timeDeadline: Saturday, 10/12/2022 23:59', 'This advert has been viewed 824 timesLocation: \n        , RWSector:\n                                              Accounting,                                              Finance and inves ...

# %%
# Creating dataframe for jobs
df = pd.DataFrame(main_dict_here)
df
# Out:
#                                        job_title        company_name  \
# 0                             Operations Manager         GardaWorld
# 1                        Account Manager- Credit              Yellow
# 2                                  Legal Manager         COPEDU PLC
# 3   District Coordinator/Junior District Manager  EarthEnable Rwanda
# 4                         Radio Sales Executives     ROYAL RADIO LTD
# ..                                           ...                 ...
# 71                              Rwanda Tree Lead       One Acre Fund
# 72             Rwanda Potato Seed Venture ﻿﻿Lead       One Acre Fund
# 73                  IT Operations Senior Manager       One Acre Fund
# 74            Rwanda Seed Innovation Centre Lead       One Acre Fund
# 75                       Senior Business Analyst       One Acre Fund
#
#                                              job_link  \
# 0   https://www.jobinrwanda.com/job/operations-man...
# 1   https://www.jobinrwanda.com/job/account-manage...
# 2       https://www.jobinrwanda.com/job/legal-manager
# 3   https://www.jobinrwanda.com/job/district-coord...
# 4   https://www.jobinrwanda.com/job/radio-sales-ex...
# ..                                                ...
# 71   https://www.jobinrwanda.com/job/rwanda-tree-lead
# 72  https://www.jobinrwanda.com/index.php/job/rwan...
# 73  https://www.jobinrwanda.com/job/it-operations-...
# 74  https://www.jobinrwanda.com/job/rwanda-seed-in...
# 75  https://www.jobinrwanda.com/job/senior-busines...
#
#                                          company_link job_category  \
# 0     https://www.jobinrwanda.com/employer/gardaworld          Job
# 1         https://www.jobinrwanda.com/employer/yellow          Job
# 2     https://www.jobinrwanda.com/employer/copedu-plc          Job
# 3   https://www.jobinrwanda.com/employer/earthenab...          Job
# 4   https://www.jobinrwanda.com/employer/royal-rad...          Job
# ..                                                ...          ...
# 71  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 72  https://www.jobinrwanda.com/index.php/employer...          Job
# 73  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 74  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 75  https://www.jobinrwanda.com/employer/one-acre-...          Job
#
#                              job_experience            published_date  \
# 0           Senior (5+ years of experience)  Published on 03-11-2022
# 1                             Not specified  Published on 27-10-2022
# 2   Mid career (3 to 5 years of experience)  Published on 12-11-2022
# 3                             Not specified  Published on 11-11-2022
# 4                             Not specified  Published on 10-11-2022
# ..                                      ...                       ...
# 71                                           Published on 15-09-2022
# 72          Senior (5+ years of experience)  Published on 14-09-2022
# 73                            Not specified  Published on 07-09-2022
# 74                                           Published on 01-09-2022
# 75                                           Published on 22-08-2022
#
#    job_deadline                                    Company_Profile  \
# 0    14-11-2022  \nGardaWorld is one of the largest privately o...
# 1    27-11-2022
# 2    18-11-2022  \nCOPEDU PLC is a microfinance institution tha...
# 3    30-11-2022  \nWho we are\nAt EarthEnable, we believe that ...
# 4    15-11-2022
# ..          ...                                                ...
# 71   20-11-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 72   28-11-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 73   06-12-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 74   29-11-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 75   17-11-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
#
#                                   company_description  \
# 0   Job Description – Operations Manager\n\nPositi...
# 1
# 2   NOTICE OF RECRUITMENT\nCOPEDU PLC, is a tradin...
# 3   JOB DESCRIPTION: DISTRICT COORDINATOR/JUNIOR D...
# 4
# ..                                                ...
# 71  About One Acre Fund\nFounded in 2006, One Acre...
# 72  About One Acre Fund\nFounded in 2006, One Acre...
# 73  About One Acre Fund\nFounded in 2006, One Acre...
# 74  About One Acre Fund\nFounded in 2006, One Acre...
# 75  ABOUT ONE ACRE FUND\nFounded in 2006, One Acre...
#
#                                           job_summary
# 0   This advert has been viewed 2297 timesLocation...
# 1   This advert has been viewed 3876 timesLocation...
# 2   This advert has been viewed 128 timesLocation:...
# 3   This advert has been viewed 1229 timesLocation...
# 4   This advert has been viewed 354 timesLocation:...
# ..                                                ...
# 71  This advert has been viewed 1677 timesLocation...
# 72  This advert has been viewed 608 timesLocation:...
# 73  This advert has been viewed 2773 timesLocation...
# 74  This advert has been viewed 1022 timesLocation...
# 75  This advert has been viewed 2092 timesLocation...
#
# [76 rows x 11 columns]

# %% [markdown]
# # scraping Consultancy

# %%
content_jobs = requests.get("https://www.jobinrwanda.com/jobs/consultancy")
soup =  BeautifulSoup(content_jobs.content, "html.parser")

# %%
def parsing_job_in_rwanda1(soup):
  main_dict = {}
  adverts_jobs = soup.find_all("div", class_="card-body p-2")
  job_title_list =[]
  company_name_list= []
  job_link_list=[]
  #company_profile = []
  company_link_list=[]
  #job_description = []
  category_list =[]
  experience_list = []
  published_date_list =[]
  deadline_list =[]

  for index, advert_job in enumerate(adverts_jobs):
    title = adverts_jobs[index].find("span", class_="field field--name-title field--type-string field--label-hidden").text
    title_link = "https://www.jobinrwanda.com"+adverts_jobs[index].find('a')['href']
    company_link = "https://www.jobinrwanda.com"+ adverts_jobs[index].find("p",class_="card-text").find("a")["href"]
    company_name = adverts_jobs[index].find("p",class_="card-text").find("a").text
    published_date = adverts_jobs[index].find("p", class_="card-text").text.split("\n")[2].strip()
    deadline = adverts_jobs[index].find('time').text
    experience = adverts_jobs[index].find("p",class_="card-text").text.split("\n")[5].strip()
    #category = adverts_jobs[index].find("p", class_="card-text").find("span", class_="badge badge-primary").text
    category = adverts_jobs[index].find("p",class_="card-text").find("span",class_="badge badge-success").getText()
               #job_posts[0].find("p",class_="card-text").find("span",class_="badge badge-primary").text
    job_title_list.append(title)
    company_name_list.append(company_name)
    job_link_list.append(title_link)
    company_link_list.append(company_link)
    category_list.append(category)
    experience_list.append(experience)
    published_date_list.append(published_date)
    deadline_list.append(deadline)

  main_dict["job_title"] = job_title_list
  main_dict["company_name"] = company_name_list
  main_dict["job_link"] = job_link_list
  main_dict["company_link"] = company_link_list
  main_dict["job_category"] = category_list
  main_dict["job_experience"] = experience_list
  main_dict["published_date"] = published_date_list
  main_dict["job_deadline"] = deadline_list

  return main_dict

# %%
main_dict_here1 =parsing_job_in_rwanda1(soup)
main_dict_here1
# Out:
# {'job_title': ['Hiring a Firm for BRD Maintenance Assessment',
#   'Consultant- Monitoring & Evaluation',
#   'Terms of Reference for Production Of the Second Generation of the Country Gender Status Report for Rwanda',
#   'Expression of Interest (EOI) Event management for the Pharma Conference in Kigali, Rwanda',
#   'Recruitment of (a) Consultancy Firm to Provide Certified AWS Re/Start Program Instructors',
#   'Consultancy Services for Service Provider for Digitizing Saving Groups in World Vision Rwanda',
#   'Short Term National Expert to Deliver Training Session\xa0on Security, Health and Environment for TVET School’s Staff',
#   'UN Dispensary Physician/ Health Manager - Head of Service – NOC level',
#   'Consultant Services to Conduct Impact Assessment for the Project “Expanding Safe Spaces for Rwandan Girls and Women With Disabilities”  ',
#   'TOR-Recruitment of a Biostatistician Consultant',
#   'Global Client Data Analytics Consultant',
#   'Expression of Interest (EOI) for Consultancy Services for Providing Management Skills Advisory for at least 15 Start-ups/SMEs',
#   'Request for Consultancy Service to Organize AYUTE Rwanda Challenge',
#   'Terms of Reference (ToR) for the Recruitment of National Short-term Consultant to deliver Trainings on Compost Making Technology for Farmers within Sebeya Catchment Project',
#   'Consultancy to Conduct Needs Assessment Study for The Capacity of Rwanda Organic Agriculture Movement(Roam) in Governance and Management to Effectively Drive the Organic Sector in Rwanda',
#   'Health Committee Consultant',
#   'Hiring of National Individual Consultant for Conducting a Study on the Status and Challenges Faced by Existing Cross Border Traders’ Cooperatives Across Rwanda Bordering Districts',
#   'Training Expert to Provide Training on Video Production and Graphic Design',
#   'Terms of Reference for Conducting a Market Landscape and Business Case Modeling Focused on Agriculture in Rwanda',
#   'Terms of Reference for Documentary Film Production\xa0for\xa0“Family Strengthening and Community Based Support for Care of Children with Disabilities in Families”\xa0Project',
#   'Terms of Reference for Programme Brief Writing for “Family Strengthening and Community Based Support for Care of Children with Disabilities in Families” Project',
#   'Terms of Reference for Midline Report Writing for “Family Strengthening and Community Based Support for Care of Children with Disabilities in Families” Project\xa0',
#   'Request for Proposals (RFP) for\xa0Consultancy Service to conduct Rapid Market Assessment of Small Livestock Productive Alliances the Heifer/PRISM Project',
#   'Consultancy Opportunity to Conduct a Formative Research on the Factors Contributing to Impairment in Children and Adolescents in Rwanda\xa0',
#   'Short Term Consultancy to Develop Tailored Loan Products for the Health Sector in Rwanda',
#   'Consultant to Conduct a Baseline Survey for Evaluating the Impacts of Covid-19 on Social-Economic Status of Cooperatives and Household’s Businesses in Karongi And Rutsiro Districts'],
#  'company_name': ['Development Bank of Rwanda (BRD)',
#   'Development Bank of Rwanda (BRD)',
#   'UN Women Rwanda',
#   'GIZ Rwanda',
#   'Smart Africa Secretariat',
#   'World Vision International Rwanda ',
#   'Expertise France',
#   'United Nations Development Programme -Rwanda',
#   'UNABU',
#   'IntraHealth',
#   'One Acre Fund',
#   'GIZ Rwanda',
#   'Heifer International Rwanda ',
#   'International Union for Conservation of Nature (IUCN)',
#   'Rwanda Organic Agriculture Movement (ROAM)',
#   'RTI International',
#   'United Nations Development Programme -Rwanda',
#   'Expertise France',
#   'CARE International Rwanda',
#   'Chance for childhood',
#   'Chance for childhood',
#   'Chance for childhood',
#   'Heifer International Rwanda ',
#   'The umbrella of Organizations of Persons with disabilities in the fight against HIV/AIDs and for health promotion (UPHLS)',
#   'Palladium Rwanda Limited ',
#   'Tubibe Amahoro (TA)'],
#  'job_link': ['https://www.jobinrwanda.com/job/hiring-firm-brd-maintenance-assessment',
#   'https://www.jobinrwanda.com/job/consultant-monitoring-evaluation-0',
#   'https://www.jobinrwanda.com/job/terms-reference-production-second-generation-country-gender-status-report-rwanda',
#   'https://www.jobinrwanda.com/job/expression-interest-eoi-event-management-pharma-conference-kigali-rwanda',
#   'https://www.jobinrwanda.com/job/recruitment-consultancy-firm-provide-certified-aws-restart-program-instructors',
#   'https://www.jobinrwanda.com/job/consultancy-services-service-provider-digitizing-saving-groups-world-vision-rwanda',
#   'https://www.jobinrwanda.com/job/short-term-national-expert-deliver-training-session-security-health-and-environment-tvet',
#   'https://www.jobinrwanda.com/job/un-dispensary-physician-health-manager-head-service-noc-level',
#   'https://www.jobinrwanda.com/job/consultant-services-conduct-impact-assessment-project-expanding-safe-spaces-rwandan-girls-and',
#   'https://www.jobinrwanda.com/job/tor-recruitment-biostatistician-consultant',
#   'https://www.jobinrwanda.com/job/global-client-data-analytics-consultant',
#   'https://www.jobinrwanda.com/job/expression-interest-eoi-consultancy-services-providing-management-skills-advisory-least-15-0',
#   'https://www.jobinrwanda.com/job/request-consultancy-service-organize-ayute-rwanda-challenge',
#   'https://www.jobinrwanda.com/job/terms-reference-tor-recruitment-national-short-term-consultant-deliver-trainings-compost-making',
#   'https://www.jobinrwanda.com/job/consultancy-conduct-needs-assessment-study-capacity-rwanda-organic-agriculture-movementroam',
#   'https://www.jobinrwanda.com/job/health-committee-consultant',
#   'https://www.jobinrwanda.com/job/hiring-national-individual-consultant-conducting-study-status-and-challenges-faced-existing',
#   'https://www.jobinrwanda.com/job/training-expert-provide-training-video-production-and-graphic-design',
#   'https://www.jobinrwanda.com/job/terms-reference-conducting-market-landscape-and-business-case-modeling-focused-agriculture',
#   'https://www.jobinrwanda.com/job/terms-reference-documentary-film-production-family-strengthening-and-community-based-support',
#   'https://www.jobinrwanda.com/job/terms-reference-programme-brief-writing-family-strengthening-and-community-based-support-care',
#   'https://www.jobinrwanda.com/job/terms-reference-midline-report-writing-family-strengthening-and-community-based-support-care',
#   'https://www.jobinrwanda.com/job/request-proposals-rfp-consultancy-service-conduct-rapid-market-assessment-small-livestock',
#   'https://www.jobinrwanda.com/job/consultancy-opportunity-conduct-formative-research-factors-contributing-impairment-children-and',
#   'https://www.jobinrwanda.com/job/short-term-consultancy-develop-tailored-loan-products-health-sector-rwanda',
#   'https://www.jobinrwanda.com/index.php/job/consultant-conduct-baseline-survey-evaluating-impacts-covid-19-social-economic-status'],
#  'company_link': ['https://www.jobinrwanda.com/employer/development-bank-rwanda-brd',
#   'https://www.jobinrwanda.com/employer/development-bank-rwanda-brd',
#   'https://www.jobinrwanda.com/employer/un-women-rwanda',
#   'https://www.jobinrwanda.com/employer/giz-rwanda',
#   'https://www.jobinrwanda.com/employer/smart-africa-secretariat',
#   'https://www.jobinrwanda.com/employer/world-vision-international-rwanda-0',
#   'https://www.jobinrwanda.com/employer/expertise-france',
#   'https://www.jobinrwanda.com/employer/united-nations-development-programme-rwanda',
#   'https://www.jobinrwanda.com/employer/unabu',
#   'https://www.jobinrwanda.com/employer/intrahealth',
#   'https://www.jobinrwanda.com/employer/one-acre-fund',
#   'https://www.jobinrwanda.com/employer/giz-rwanda',
#   'https://www.jobinrwanda.com/employer/heifer-international-rwanda',
#   'https://www.jobinrwanda.com/employer/international-union-conservation-nature-iucn',
#   'https://www.jobinrwanda.com/employer/rwanda-organic-agriculture-movement-roam',
#   'https://www.jobinrwanda.com/employer/rti-international',
#   'https://www.jobinrwanda.com/employer/united-nations-development-programme-rwanda',
#   'https://www.jobinrwanda.com/employer/expertise-france',
#   'https://www.jobinrwanda.com/employer/care-international-rwanda',
#   'https://www.jobinrwanda.com/employer/chance-childhood',
#   'https://www.jobinrwanda.com/employer/chance-childhood',
#   'https://www.jobinrwanda.com/employer/chance-childhood',
#   'https://www.jobinrwanda.com/employer/heifer-international-rwanda',
#   'https://www.jobinrwanda.com/employer/umbrella-organizations-persons-disabilities-fight-against-hivaids-and-health-promotion',
#   'https://www.jobinrwanda.com/employer/palladium-rwanda-limited',
#   'https://www.jobinrwanda.com/index.php/employer/tubibe-amahoro-ta'],
#  'job_category': ['Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy',
#   'Consultancy'],
#  'job_experience': ['Not specified',
#   'Not specified',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   '',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Not specified',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Senior (5+ years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Mid career (3 to 5 years of experience)',
#   'Not specified',
#   'Not specified',
#   'Senior (5+ years of experience)',
#   'Entry level (1 to 3 years of experience)',
#   'Not specified'],
#  'published_date': ['Published on 10-11-2022 |',
#   'Published on 09-11-2022 |',
#   'Published on 02-11-2022 |',
#   'Published on 11-11-2022 |',
#   'Published on 11-11-2022 |',
#   'Published on 10-11-2022 |',
#   'Published on 10-11-2022 |',
#   'Published on 11-11-2022 |',
#   'Published on 10-11-2022 |',
#   'Published on 09-11-2022 |',
#   'Published on 08-11-2022 |',
#   'Published on 07-11-2022 |',
#   'Published on 07-11-2022 |',
#   'Published on 07-11-2022 |',
#   'Published on 04-11-2022 |',
#   'Published on 04-11-2022 |',
#   'Published on 03-11-2022 |',
#   'Published on 03-11-2022 |',
#   'Published on 03-11-2022 |',
#   'Published on 01-11-2022 |',
#   'Published on 01-11-2022 |',
#   'Published on 01-11-2022 |',
#   'Published on 01-11-2022 |',
#   'Published on 31-10-2022 |',
#   'Published on 31-10-2022 |',
#   'Published on 03-10-2022 |'],
#  'job_deadline': ['25-11-2022',
#   '08-12-2022',
#   '15-11-2022',
#   '25-11-2022',
#   '09-12-2022',
#   '29-11-2022',
#   '17-11-2022',
#   '06-12-2022',
#   '18-11-2022',
#   '21-11-2022',
#   '20-12-2022',
#   '21-11-2022',
#   '18-11-2022',
#   '20-11-2022',
#   '15-11-2022',
#   '13-11-2022',
#   '15-11-2022',
#   '14-11-2022',
#   '30-11-2022',
#   '14-11-2022',
#   '14-11-2022',
#   '14-11-2022',
#   '14-11-2022',
#   '15-11-2022',
#   '15-11-2022',
#   '15-11-2022']}

# %%
# looping through consultancy description

company_profile1 = []
company_description1 = []
job_summary11= []

for link in main_dict_here1["job_link"]:
  company_page = requests.get(link).content
  #job_description_raw_content = requests.get('https://www.jobinrwanda.com/job/global-remote-sensing-manager').content

  soup_company_page = BeautifulSoup(company_page,'html.parser')
  employer_page = soup_company_page.find_all('div', class_='employer-description') #Employer Description
  describe = soup_company_page.find_all('div', class_="clearfix text-formatted field field--name-field-job-full-description field--type-text-long field--label-hidden field__item") #Employer Description
  company_prof = ''
  company_desc = ''
   #Construct an empty string to hold the paragraph
  for index,emp_page in enumerate(employer_page):
    for textt in employer_page[0].text.split('\n'):
      company_prof += textt +'\n'
    description1 = ''
    for paragraph in describe:
      description1 += paragraph.getText() #Adding each paragraph we find in the job description.

  for textt in description1.split('\n'):
    company_desc += textt +'\n'
  soup_company_page=BeautifulSoup(company_page,'html.parser')
  #s_soup1 = soup_company_page.find("div",class_="card-header bg-primary").getText().strip()
  #print(s_soup1)
  s_soup2 = soup_company_page.find_all("div",class_="card border-primary sidebar-block")[0].find_all('ul', class_="list-group list-group-flush")[0].find_all('li')[:7]
  summary1=''
  for ss in s_soup2:
    summary1 +=ss.getText().strip()

  
  company_description1.append(company_desc)
  company_profile1.append(company_prof)
  job_summary11.append(summary1)

# %%
main_dict_here1["Company_Profile"] = company_profile1
main_dict_here1["company_description"] = company_description1
main_dict_here1["job_summary"] = job_summary11

# %%
print(len(main_dict_here1))
# Out:
# 11

# %%
df1 = pd.DataFrame(main_dict_here1)
df1
# Out:
#                                             job_title  \
# 0        Hiring a Firm for BRD Maintenance Assessment
# 1                 Consultant- Monitoring & Evaluation
# 2   Terms of Reference for Production Of the Secon...
# 3   Expression of Interest (EOI) Event management ...
# 4   Recruitment of (a) Consultancy Firm to Provide...
# 5   Consultancy Services for Service Provider for ...
# 6   Short Term National Expert to Deliver Training...
# 7   UN Dispensary Physician/ Health Manager - Head...
# 8   Consultant Services to Conduct Impact Assessme...
# 9     TOR-Recruitment of a Biostatistician Consultant
# 10            Global Client Data Analytics Consultant
# 11  Expression of Interest (EOI) for Consultancy S...
# 12  Request for Consultancy Service to Organize AY...
# 13  Terms of Reference (ToR) for the Recruitment o...
# 14  Consultancy to Conduct Needs Assessment Study ...
# 15                        Health Committee Consultant
# 16  Hiring of National Individual Consultant for C...
# 17  Training Expert to Provide Training on Video P...
# 18  Terms of Reference for Conducting a Market Lan...
# 19  Terms of Reference for Documentary Film Produc...
# 20  Terms of Reference for Programme Brief Writing...
# 21  Terms of Reference for Midline Report Writing ...
# 22  Request for Proposals (RFP) for Consultancy Se...
# 23  Consultancy Opportunity to Conduct a Formative...
# 24  Short Term Consultancy to Develop Tailored Loa...
# 25  Consultant to Conduct a Baseline Survey for Ev...
#
#                                          company_name  \
# 0                    Development Bank of Rwanda (BRD)
# 1                    Development Bank of Rwanda (BRD)
# 2                                     UN Women Rwanda
# 3                                          GIZ Rwanda
# 4                            Smart Africa Secretariat
# 5                  World Vision International Rwanda
# 6                                    Expertise France
# 7        United Nations Development Programme -Rwanda
# 8                                               UNABU
# 9                                         IntraHealth
# 10                                      One Acre Fund
# 11                                         GIZ Rwanda
# 12                       Heifer International Rwanda
# 13  International Union for Conservation of Nature...
# 14         Rwanda Organic Agriculture Movement (ROAM)
# 15                                  RTI International
# 16       United Nations Development Programme -Rwanda
# 17                                   Expertise France
# 18                          CARE International Rwanda
# 19                               Chance for childhood
# 20                               Chance for childhood
# 21                               Chance for childhood
# 22                       Heifer International Rwanda
# 23  The umbrella of Organizations of Persons with ...
# 24                          Palladium Rwanda Limited
# 25                                Tubibe Amahoro (TA)
#
#                                              job_link  \
# 0   https://www.jobinrwanda.com/job/hiring-firm-br...
# 1   https://www.jobinrwanda.com/job/consultant-mon...
# 2   https://www.jobinrwanda.com/job/terms-referenc...
# 3   https://www.jobinrwanda.com/job/expression-int...
# 4   https://www.jobinrwanda.com/job/recruitment-co...
# 5   https://www.jobinrwanda.com/job/consultancy-se...
# 6   https://www.jobinrwanda.com/job/short-term-nat...
# 7   https://www.jobinrwanda.com/job/un-dispensary-...
# 8   https://www.jobinrwanda.com/job/consultant-ser...
# 9   https://www.jobinrwanda.com/job/tor-recruitmen...
# 10  https://www.jobinrwanda.com/job/global-client-...
# 11  https://www.jobinrwanda.com/job/expression-int...
# 12  https://www.jobinrwanda.com/job/request-consul...
# 13  https://www.jobinrwanda.com/job/terms-referenc...
# 14  https://www.jobinrwanda.com/job/consultancy-co...
# 15  https://www.jobinrwanda.com/job/health-committ...
# 16  https://www.jobinrwanda.com/job/hiring-nationa...
# 17  https://www.jobinrwanda.com/job/training-exper...
# 18  https://www.jobinrwanda.com/job/terms-referenc...
# 19  https://www.jobinrwanda.com/job/terms-referenc...
# 20  https://www.jobinrwanda.com/job/terms-referenc...
# 21  https://www.jobinrwanda.com/job/terms-referenc...
# 22  https://www.jobinrwanda.com/job/request-propos...
# 23  https://www.jobinrwanda.com/job/consultancy-op...
# 24  https://www.jobinrwanda.com/job/short-term-con...
# 25  https://www.jobinrwanda.com/index.php/job/cons...
#
#                                          company_link job_category  \
# 0   https://www.jobinrwanda.com/employer/developme...  Consultancy
# 1   https://www.jobinrwanda.com/employer/developme...  Consultancy
# 2   https://www.jobinrwanda.com/employer/un-women-...  Consultancy
# 3     https://www.jobinrwanda.com/employer/giz-rwanda  Consultancy
# 4   https://www.jobinrwanda.com/employer/smart-afr...  Consultancy
# 5   https://www.jobinrwanda.com/employer/world-vis...  Consultancy
# 6   https://www.jobinrwanda.com/employer/expertise...  Consultancy
# 7   https://www.jobinrwanda.com/employer/united-na...  Consultancy
# 8          https://www.jobinrwanda.com/employer/unabu  Consultancy
# 9    https://www.jobinrwanda.com/employer/intrahealth  Consultancy
# 10  https://www.jobinrwanda.com/employer/one-acre-...  Consultancy
# 11    https://www.jobinrwanda.com/employer/giz-rwanda  Consultancy
# 12  https://www.jobinrwanda.com/employer/heifer-in...  Consultancy
# 13  https://www.jobinrwanda.com/employer/internati...  Consultancy
# 14  https://www.jobinrwanda.com/employer/rwanda-or...  Consultancy
# 15  https://www.jobinrwanda.com/employer/rti-inter...  Consultancy
# 16  https://www.jobinrwanda.com/employer/united-na...  Consultancy
# 17  https://www.jobinrwanda.com/employer/expertise...  Consultancy
# 18  https://www.jobinrwanda.com/employer/care-inte...  Consultancy
# 19  https://www.jobinrwanda.com/employer/chance-ch...  Consultancy
# 20  https://www.jobinrwanda.com/employer/chance-ch...  Consultancy
# 21  https://www.jobinrwanda.com/employer/chance-ch...  Consultancy
# 22  https://www.jobinrwanda.com/employer/heifer-in...  Consultancy
# 23  https://www.jobinrwanda.com/employer/umbrella-...  Consultancy
# 24  https://www.jobinrwanda.com/employer/palladium...  Consultancy
# 25  https://www.jobinrwanda.com/index.php/employer...  Consultancy
#
#                               job_experience             published_date  \
# 0                              Not specified  Published on 10-11-2022 |
# 1                              Not specified  Published on 09-11-2022 |
# 2            Senior (5+ years of experience)  Published on 02-11-2022 |
# 3            Senior (5+ years of experience)  Published on 11-11-2022 |
# 4            Senior (5+ years of experience)  Published on 11-11-2022 |
# 5                                             Published on 10-11-2022 |
# 6            Senior (5+ years of experience)  Published on 10-11-2022 |
# 7            Senior (5+ years of experience)  Published on 11-11-2022 |
# 8            Senior (5+ years of experience)  Published on 10-11-2022 |
# 9            Senior (5+ years of experience)  Published on 09-11-2022 |
# 10           Senior (5+ years of experience)  Published on 08-11-2022 |
# 11           Senior (5+ years of experience)  Published on 07-11-2022 |
# 12                             Not specified  Published on 07-11-2022 |
# 13           Senior (5+ years of experience)  Published on 07-11-2022 |
# 14           Senior (5+ years of experience)  Published on 04-11-2022 |
# 15           Senior (5+ years of experience)  Published on 04-11-2022 |
# 16           Senior (5+ years of experience)  Published on 03-11-2022 |
# 17           Senior (5+ years of experience)  Published on 03-11-2022 |
# 18           Senior (5+ years of experience)  Published on 03-11-2022 |
# 19   Mid career (3 to 5 years of experience)  Published on 01-11-2022 |
# 20   Mid career (3 to 5 years of experience)  Published on 01-11-2022 |
# 21                             Not specified  Published on 01-11-2022 |
# 22                             Not specified  Published on 01-11-2022 |
# 23           Senior (5+ years of experience)  Published on 31-10-2022 |
# 24  Entry level (1 to 3 years of experience)  Published on 31-10-2022 |
# 25                             Not specified  Published on 03-10-2022 |
#
#    job_deadline                                    Company_Profile  \
# 0    25-11-2022  \nThe Development Bank of Rwanda Plc “BRD”, a ...
# 1    08-12-2022  \nThe Development Bank of Rwanda Plc “BRD”, a ...
# 2    15-11-2022  \nRwanda is among eight pilot countries select...
# 3    25-11-2022
# 4    09-12-2022
# 5    29-11-2022
# 6    17-11-2022  \nExpertise France is the French international...
# 7    06-12-2022  \nRwanda is among eight pilot countries select...
# 8    18-11-2022  \n \nUNABU (Umuryango Nyarwanda w'Abagore Bafi...
# 9    21-11-2022  \n\n\n\n\n\n\n\nFor over 35 years in 100 count...
# 10   20-12-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 11   21-11-2022
# 12   18-11-2022  \nWe support farmers to set up their own coope...
# 13   20-11-2022  \nIUCN is a membership Union composed of both ...
# 14   15-11-2022  \nRwanda Organic Agriculture Movement (ROAM) i...
# 15   13-11-2022  \nRTI International has worked in Rwanda for 3...
# 16   15-11-2022  \nRwanda is among eight pilot countries select...
# 17   14-11-2022  \nExpertise France is the French international...
# 18   30-11-2022
# 19   14-11-2022  \nChance for Childhood is an international cha...
# 20   14-11-2022  \nChance for Childhood is an international cha...
# 21   14-11-2022  \nChance for Childhood is an international cha...
# 22   14-11-2022  \nWe support farmers to set up their own coope...
# 23   15-11-2022
# 24   15-11-2022  \nPalladium is a global leader in the design, ...
# 25   15-11-2022  \nTubibe Amahoro (TA) is a not-for-profit orga...
#
#                                   company_description  \
# 0   RE-ADVERTISEMENT OF TENDER : Nº: 022/10/2022/B...
# 1   RE-ADVERTISEMENT OF TENDER : RFP No. 017/08/20...
# 2   TERMS OF REFERENCE FOR PRODUCTION OF THE SECON...
# 3   TERMS OF REFERENCE FOR PRODUCTION OF THE SECON...
# 4   TERMS OF REFERENCE FOR PRODUCTION OF THE SECON...
# 5   TERMS OF REFERENCE FOR PRODUCTION OF THE SECON...
# 6   Job description: short term national expert to...
# 7   United  Nations\nCORE VALUES: INTEGRITY, PROFE...
# 8   CONSULTANT SERVICES TO CONDUCT IMPACT ASSESSEM...
# 9   \n\nINGOBYI ACTIVITY\nGOLDEN PLAZA, 3rd Floor\...
# 10  About One Acre Fund\nFounded in 2006, One Acre...
# 11  About One Acre Fund\nFounded in 2006, One Acre...
# 12  Advertisement for Consultancy service To Organ...
# 13  Terms of Reference (ToR) for the recruitment o...
# 14  CONSULTANCY TO CONDUCT NEEDS ASSESSMENT STUDY ...
# 15  RTI (www.rti.org) is an independent, non-profi...
# 16  Description of the assignment: HIRING OF NATIO...
# 17  Job description: Training Expert to provide tr...
# 18  Job description: Training Expert to provide tr...
# 19  Terms of Reference\nDOCUMENTARY FILM PRODUCTIO...
# 20  Terms of Reference\nPROGRAMME BRIEF WRITING fo...
# 21  Terms of Reference\nMIDLINE REPORT WRITING for...
# 22  Advertisement for Procurement\nRequest for Pro...
# 23  Advertisement for Procurement\nRequest for Pro...
# 24  Short Term Consultancy to Develop Tailored Loa...
# 25  CONSULTANT TO CONDUCT A BASELINE SURVEY FOR EV...
#
#                                           job_summary
# 0   This advert has been viewed 229 timesLocation:...
# 1   This advert has been viewed 511 timesLocation:...
# 2   This advert has been viewed 645 timesLocation:...
# 3   This advert has been viewed 123 timesLocation:...
# 4   This advert has been viewed 55 timesLocation: ...
# 5   This advert has been viewed 154 timesLocation:...
# 6   This advert has been viewed 126 timesLocation:...
# 7   This advert has been viewed 153 timesLocation:...
# 8   This advert has been viewed 121 timesLocation:...
# 9   This advert has been viewed 135 timesLocation:...
# 10  This advert has been viewed 133 timesLocation:...
# 11  This advert has been viewed 299 timesLocation:...
# 12  This advert has been viewed 178 timesLocation:...
# 13  This advert has been viewed 482 timesLocation:...
# 14  This advert has been viewed 181 timesLocation:...
# 15  This advert has been viewed 422 timesLocation:...
# 16  This advert has been viewed 372 timesLocation:...
# 17  This advert has been viewed 285 timesLocation:...
# 18  This advert has been viewed 198 timesLocation:...
# 19  This advert has been viewed 389 timesLocation:...
# 20  This advert has been viewed 164 timesLocation:...
# 21  This advert has been viewed 189 timesLocation:...
# 22  This advert has been viewed 294 timesLocation:...
# 23  This advert has been viewed 336 timesLocation:...
# 24  This advert has been viewed 162 timesLocation:...
# 25  This advert has been viewed 1033 timesLocation...

# %%
df1["job_summary"]
# Out:
# 0     This advert has been viewed 229 timesLocation:...
# 1     This advert has been viewed 511 timesLocation:...
# 2     This advert has been viewed 645 timesLocation:...
# 3     This advert has been viewed 123 timesLocation:...
# 4     This advert has been viewed 55 timesLocation: ...
# 5     This advert has been viewed 154 timesLocation:...
# 6     This advert has been viewed 126 timesLocation:...
# 7     This advert has been viewed 153 timesLocation:...
# 8     This advert has been viewed 121 timesLocation:...
# 9     This advert has been viewed 135 timesLocation:...
# 10    This advert has been viewed 133 timesLocation:...
# 11    This advert has been viewed 299 timesLocation:...
# 12    This advert has been viewed 178 timesLocation:...
# 13    This advert has been viewed 482 timesLocation:...
# 14    This advert has been viewed 181 timesLocation:...
# 15    This advert has been viewed 422 timesLocation:...
# 16    This advert has been viewed 372 timesLocation:...
# 17    This advert has been viewed 285 timesLocation:...
# 18    This advert has been viewed 198 timesLocation:...
# 19    This advert has been viewed 389 timesLocation:...
# 20    This advert has been viewed 164 timesLocation:...
# 21    This advert has been viewed 189 timesLocation:...
# 22    This advert has been viewed 294 timesLocation:...
# 23    This advert has been viewed 336 timesLocation:...
# 24    This advert has been viewed 162 timesLocation:...
# 25    This advert has been viewed 1033 timesLocation...
# Name: job_summary, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            26 non-null     object
#  1   company_name         26 non-null     object
#  2   job_link             26 non-null     object
#  3   company_link         26 non-null     object
#  4   job_category         26 non-null     object
#  5   job_experience       26 non-null     object
#  6   published_date       26 non-null     object
#  7   job_deadline         26 non-null     object
#  8   Company_Profile      26 non-null     object
#  9   company_description  26 non-null     object
#  10  job_summary          26 non-null     object
# dtypes: object(11)
# memory usage: 2.4+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            76 non-null     object
#  1   company_name         76 non-null     object
#  2   job_link             76 non-null     object
#  3   company_link         76 non-null     object
#  4   job_category         76 non-null     object
#  5   job_experience       76 non-null     object
#  6   published_date       76 non-null     object
#  7   job_deadline         76 non-null     object
#  8   Company_Profile      76 non-null     object
#  9   company_description  76 non-null     object
#  10  job_summary          76 non-null     object
# dtypes: object(11)
# memory usage: 6.7+ KB

# %% [markdown]
# # Concatenating two data frames

# %%
df_result = pd.concat([df, df1], ignore_index=True, sort=False)
df_result
# Out:
#                                              job_title  \
# 0                                   Operations Manager
# 1                              Account Manager- Credit
# 2                                        Legal Manager
# 3         District Coordinator/Junior District Manager
# 4                               Radio Sales Executives
# ..                                                 ...
# 97   Terms of Reference for Midline Report Writing ...
# 98   Request for Proposals (RFP) for Consultancy Se...
# 99   Consultancy Opportunity to Conduct a Formative...
# 100  Short Term Consultancy to Develop Tailored Loa...
# 101  Consultant to Conduct a Baseline Survey for Ev...
#
#                                           company_name  \
# 0                                          GardaWorld
# 1                                               Yellow
# 2                                          COPEDU PLC
# 3                                   EarthEnable Rwanda
# 4                                      ROYAL RADIO LTD
# ..                                                 ...
# 97                                Chance for childhood
# 98                        Heifer International Rwanda
# 99   The umbrella of Organizations of Persons with ...
# 100                          Palladium Rwanda Limited
# 101                                Tubibe Amahoro (TA)
#
#                                               job_link  \
# 0    https://www.jobinrwanda.com/job/operations-man...
# 1    https://www.jobinrwanda.com/job/account-manage...
# 2        https://www.jobinrwanda.com/job/legal-manager
# 3    https://www.jobinrwanda.com/job/district-coord...
# 4    https://www.jobinrwanda.com/job/radio-sales-ex...
# ..                                                 ...
# 97   https://www.jobinrwanda.com/job/terms-referenc...
# 98   https://www.jobinrwanda.com/job/request-propos...
# 99   https://www.jobinrwanda.com/job/consultancy-op...
# 100  https://www.jobinrwanda.com/job/short-term-con...
# 101  https://www.jobinrwanda.com/index.php/job/cons...
#
#                                           company_link job_category  \
# 0      https://www.jobinrwanda.com/employer/gardaworld          Job
# 1          https://www.jobinrwanda.com/employer/yellow          Job
# 2      https://www.jobinrwanda.com/employer/copedu-plc          Job
# 3    https://www.jobinrwanda.com/employer/earthenab...          Job
# 4    https://www.jobinrwanda.com/employer/royal-rad...          Job
# ..                                                 ...          ...
# 97   https://www.jobinrwanda.com/employer/chance-ch...  Consultancy
# 98   https://www.jobinrwanda.com/employer/heifer-in...  Consultancy
# 99   https://www.jobinrwanda.com/employer/umbrella-...  Consultancy
# 100  https://www.jobinrwanda.com/employer/palladium...  Consultancy
# 101  https://www.jobinrwanda.com/index.php/employer...  Consultancy
#
#                                job_experience             published_date  \
# 0             Senior (5+ years of experience)   Published on 03-11-2022
# 1                               Not specified   Published on 27-10-2022
# 2     Mid career (3 to 5 years of experience)   Published on 12-11-2022
# 3                               Not specified   Published on 11-11-2022
# 4                               Not specified   Published on 10-11-2022
# ..                                        ...                        ...
# 97                              Not specified  Published on 01-11-2022 |
# 98                              Not specified  Published on 01-11-2022 |
# 99            Senior (5+ years of experience)  Published on 31-10-2022 |
# 100  Entry level (1 to 3 years of experience)  Published on 31-10-2022 |
# 101                             Not specified  Published on 03-10-2022 |
#
#     job_deadline                                    Company_Profile  \
# 0     14-11-2022  \nGardaWorld is one of the largest privately o...
# 1     27-11-2022
# 2     18-11-2022  \nCOPEDU PLC is a microfinance institution tha...
# 3     30-11-2022  \nWho we are\nAt EarthEnable, we believe that ...
# 4     15-11-2022
# ..           ...                                                ...
# 97    14-11-2022  \nChance for Childhood is an international cha...
# 98    14-11-2022  \nWe support farmers to set up their own coope...
# 99    15-11-2022
# 100   15-11-2022  \nPalladium is a global leader in the design, ...
# 101   15-11-2022  \nTubibe Amahoro (TA) is a not-for-profit orga...
#
#                                    company_description  \
# 0    Job Description – Operations Manager\n\nPositi...
# 1
# 2    NOTICE OF RECRUITMENT\nCOPEDU PLC, is a tradin...
# 3    JOB DESCRIPTION: DISTRICT COORDINATOR/JUNIOR D...
# 4
# ..                                                 ...
# 97   Terms of Reference\nMIDLINE REPORT WRITING for...
# 98   Advertisement for Procurement\nRequest for Pro...
# 99   Advertisement for Procurement\nRequest for Pro...
# 100  Short Term Consultancy to Develop Tailored Loa...
# 101  CONSULTANT TO CONDUCT A BASELINE SURVEY FOR EV...
#
#                                            job_summary
# 0    This advert has been viewed 2297 timesLocation...
# 1    This advert has been viewed 3876 timesLocation...
# 2    This advert has been viewed 128 timesLocation:...
# 3    This advert has been viewed 1229 timesLocation...
# 4    This advert has been viewed 354 timesLocation:...
# ..                                                 ...
# 97   This advert has been viewed 189 timesLocation:...
# 98   This advert has been viewed 294 timesLocation:...
# 99   This advert has been viewed 336 timesLocation:...
# 100  This advert has been viewed 162 timesLocation:...
# 101  This advert has been viewed 1033 timesLocation...
#
# [102 rows x 11 columns]

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            102 non-null    object
#  1   company_name         102 non-null    object
#  2   job_link             102 non-null    object
#  3   company_link         102 non-null    object
#  4   job_category         102 non-null    object
#  5   job_experience       102 non-null    object
#  6   published_date       102 non-null    object
#  7   job_deadline         102 non-null    object
#  8   Company_Profile      102 non-null    object
#  9   company_description  102 non-null    object
#  10  job_summary          102 non-null    object
# dtypes: object(11)
# memory usage: 8.9+ KB

# %% [markdown]
# # IT related jobs from the above dataset

# %%
import re
tags = "#ICT#informationtechnology #technology #it #cybersecurity #tech #computerscience #programming  #coding #innovation #software #python #information #computer #informationsecurity #security #technologynews #java #networking #hacking #programmer #linux #technologyrocks #coder #technologythesedays #cloudcomputing  #engineering #itservices #newtechnology"
sss = tags.split('#')[1:]
sss_strip =[]
for tag in sss:
  sss_strip.append(tag.strip())
sss_strip
# Out:
# ['ICT',
#  'informationtechnology',
#  'technology',
#  'it',
#  'cybersecurity',
#  'tech',
#  'computerscience',
#  'programming',
#  'coding',
#  'innovation',
#  'software',
#  'python',
#  'information',
#  'computer',
#  'informationsecurity',
#  'security',
#  'technologynews',
#  'java',
#  'networking',
#  'hacking',
#  'programmer',
#  'linux',
#  'technologyrocks',
#  'coder',
#  'technologythesedays',
#  'cloudcomputing',
#  'engineering',
#  'itservices',
#  'newtechnology']

# %%
# Creating an empty dataframe to store IT related Jobs

df_jobs = pd.DataFrame()
df_jobs
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for index1, row in enumerate(df_result['job_summary']):
  for it_job in sss_strip:
    pattern = re.compile(f"\s?{it_job}\s?")
    #pattern = re.compile(f"\s?{it}\s?")
    matches = pattern.findall(str(df_result["job_summary"][index1].split("\n")[2].split("Other")[0].strip().lower()))
    if matches != []:
      df3=df_result.iloc[index1:index1+1,:]
      df_jobs=pd.concat([df_jobs,df3])

df_jobs
# Out:
#                                  job_title  \
# 8                          Product Manager
# 8                          Product Manager
# 9   Aftercare/ Vehicle Maintenance Manager
# 12     Lecturer, Communication and Writing
# 41                     IT and MIS Director
# 41                     IT and MIS Director
# 45           Global Remote Sensing Manager
# 45           Global Remote Sensing Manager
# 53     Instructional Technology Assistant
# 53     Instructional Technology Assistant
# 70          Rwanda Electrical Hub Operator
# 73            IT Operations Senior Manager
# 73            IT Operations Senior Manager
#
#                                  company_name  \
# 8                        Ampersand Rwanda Ltd
# 8                        Ampersand Rwanda Ltd
# 9                        Ampersand Rwanda Ltd
# 12  University of Global Health Equity (UGHE)
# 41               CHANCEN International Rwanda
# 41               CHANCEN International Rwanda
# 45                              One Acre Fund
# 45                              One Acre Fund
# 53  University of Global Health Equity (UGHE)
# 53  University of Global Health Equity (UGHE)
# 70                              One Acre Fund
# 73                              One Acre Fund
# 73                              One Acre Fund
#
#                                              job_link  \
# 8   https://www.jobinrwanda.com/job/product-manager-1
# 8   https://www.jobinrwanda.com/job/product-manager-1
# 9   https://www.jobinrwanda.com/job/aftercare-vehi...
# 12  https://www.jobinrwanda.com/job/lecturer-commu...
# 41  https://www.jobinrwanda.com/job/it-and-mis-dir...
# 41  https://www.jobinrwanda.com/job/it-and-mis-dir...
# 45  https://www.jobinrwanda.com/job/global-remote-...
# 45  https://www.jobinrwanda.com/job/global-remote-...
# 53  https://www.jobinrwanda.com/job/instructional-...
# 53  https://www.jobinrwanda.com/job/instructional-...
# 70  https://www.jobinrwanda.com/job/rwanda-electri...
# 73  https://www.jobinrwanda.com/job/it-operations-...
# 73  https://www.jobinrwanda.com/job/it-operations-...
#
#                                          company_link job_category  \
# 8   https://www.jobinrwanda.com/employer/ampersand...          Job
# 8   https://www.jobinrwanda.com/employer/ampersand...          Job
# 9   https://www.jobinrwanda.com/employer/ampersand...          Job
# 12  https://www.jobinrwanda.com/employer/universit...          Job
# 41  https://www.jobinrwanda.com/employer/chancen-i...          Job
# 41  https://www.jobinrwanda.com/employer/chancen-i...          Job
# 45  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 45  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 53  https://www.jobinrwanda.com/employer/universit...          Job
# 53  https://www.jobinrwanda.com/employer/universit...          Job
# 70  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 73  https://www.jobinrwanda.com/employer/one-acre-...          Job
# 73  https://www.jobinrwanda.com/employer/one-acre-...          Job
#
#                              job_experience            published_date  \
# 8           Senior (5+ years of experience)  Published on 10-11-2022
# 8           Senior (5+ years of experience)  Published on 10-11-2022
# 9           Senior (5+ years of experience)  Published on 10-11-2022
# 12  Mid career (3 to 5 years of experience)  Published on 09-11-2022
# 41          Senior (5+ years of experience)  Published on 31-10-2022
# 41          Senior (5+ years of experience)  Published on 31-10-2022
# 45  Mid career (3 to 5 years of experience)  Published on 31-10-2022
# 45  Mid career (3 to 5 years of experience)  Published on 31-10-2022
# 53                            Not specified  Published on 28-10-2022
# 53                            Not specified  Published on 28-10-2022
# 70                                           Published on 12-10-2022
# 73                            Not specified  Published on 07-09-2022
# 73                            Not specified  Published on 07-09-2022
#
#    job_deadline                                    Company_Profile  \
# 8    10-01-2023  \nAmpersand is an energy and mobility startup ...
# 8    10-01-2023  \nAmpersand is an energy and mobility startup ...
# 9    10-12-2022  \nAmpersand is an energy and mobility startup ...
# 12   09-12-2022
# 41   18-11-2022  \nWe are a not-for-profit organisation that pr...
# 41   18-11-2022  \nWe are a not-for-profit organisation that pr...
# 45   25-01-2023  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 45   25-01-2023  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 53   28-11-2022
# 53   28-11-2022
# 70   19-11-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 73   06-12-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
# 73   06-12-2022  \nFounded in 2006, One Acre Fund supplies 1 mi...
#
#                                   company_description  \
# 8   Do you want to do work that matters? Do you wa...
# 8   Do you want to do work that matters? Do you wa...
# 9   Do you want to do work that is impactful? Do y...
# 12
# 41  CHANCEN International is a non-profit organiza...
# 41  CHANCEN International is a non-profit organiza...
# 45  About One Acre Fund\nFounded in 2006, One Acre...
# 45  About One Acre Fund\nFounded in 2006, One Acre...
# 53
# 53
# 70  About One Acre Fund\nFounded in 2006, One Acre...
# 73  About One Acre Fund\nFounded in 2006, One Acre...
# 73  About One Acre Fund\nFounded in 2006, One Acre...
#
#                                           job_summary
# 8   This advert has been viewed 311 timesLocation:...
# 8   This advert has been viewed 311 timesLocation:...
# 9   This advert has been viewed 188 timesLocation:...
# 12  This advert has been viewed 297 timesLocation:...
# 41  This advert has been viewed 1516 timesLocation...
# 41  This advert has been viewed 1516 timesLocation...
# 45  This advert has been viewed 362 timesLocation:...
# 45  This advert has been viewed 362 timesLocation:...
# 53  This advert has been viewed 824 timesLocation:...
# 53  This advert has been viewed 824 timesLocation:...
# 70  This advert has been viewed 1234 timesLocation...
# 73  This advert has been viewed 2773 timesLocation...
# 73  This advert has been viewed 2773 timesLocation...

# %%
df_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 8 to 73
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_title            13 non-null     object
#  1   company_name         13 non-null     object
#  2   job_link             13 non-null     object
#  3   company_link         13 non-null     object
#  4   job_category         13 non-null     object
#  5   job_experience       13 non-null     object
#  6   published_date       13 non-null     object
#  7   job_deadline         13 non-null     object
#  8   Company_Profile      13 non-null     object
#  9   company_description  13 non-null     object
#  10  job_summary          13 non-null     object
# dtypes: object(11)
# memory usage: 1.2+ KB

# %% [markdown]
# # Translating

# %%
# !pip install -U easynmt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting easynmt
#   Downloading EasyNMT-2.0.2.tar.gz (23 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from easynmt) (4.64.1)
# Collecting transformers<5,>=4.4
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 11.3 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from easynmt) (1.12.1+cu113)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from easynmt) (1.21.6)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from easynmt) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 39.3 MB/s
# Collecting fasttext
#   Downloading fasttext-0.9.2.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 7.1 MB/s
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from easynmt) (3.19.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->easynmt) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (4.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5,>=4.4->easynmt) (21.3)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 42.5 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 40.2 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5,>=4.4->easynmt) (3.0.9)
# Collecting pybind11>=2.2
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext->easynmt) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5,>=4.4->easynmt) (3.10.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk->easynmt) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk->easynmt) (7.1.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5,>=4.4->easynmt) (2022.9.24)
# Building wheels for collected packages: easynmt, fasttext
#   Building wheel for easynmt (setup.py) ... done
#   Created wheel for easynmt: filename=EasyNMT-2.0.2-py3-none-any.whl size=19919 sha256=a31467406ffaff499ed9340be64d4f93f1cd13a971e71410bd26d6a5f994b95e
#   Stored in directory: /root/.cache/pip/wheels/d1/57/06/53ca38645e14d4537a41e5a36da2026e10f54ae88240dd5190
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3164406 sha256=aacb7b88866b3c3c74a54dc108136a2cb35cccae512496b8837e1924df3b2be0
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# Successfully built easynmt fasttext
# Installing collected packages: tokenizers, pybind11, huggingface-hub, transformers, sentencepiece, fasttext, easynmt
# Successfully installed easynmt-2.0.2 fasttext-0.9.2 huggingface-hub-0.10.1 pybind11-2.10.1 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.24.0

# %%
from easynmt import EasyNMT
#model = EasyNMT('opus-mt')
#model = EasyNMT('opus-mt', max_loaded_models=10)
model = EasyNMT('mbart50_en2m')


this_arr=[]

df_translated = pd.DataFrame()
for transl_col in ['job_title', 'company_name','job_experience','published_date','job_deadline','Company_Profile','company_description', 'job_summary']:
  

  for index2, row2 in enumerate(df_result[transl_col]):
  
    Translations = model.translate(row2,target_lang='fr') 
    df_result[transl_col][index2]=Translations
    this_arr.append(Translations)
    df4=df_result.iloc[index2:index2+1,:]
    df_translated=pd.concat([df_translated,df4])
  
df_translated
# Out:
# 1.47kB [00:00, 558kB/s]
# Downloading:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/528 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/717 [00:00<?, ?B/s]
# 100%|██████████| 938k/938k [00:00<00:00, 2.85MB/s]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 200 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,

# %%
df_translated['job_summary']

# %%
df_translated['company_description']

# %% [markdown]
# # UMUCYO Tenders

# %%
umucyo_web_page =  requests.get('https://www.umucyo.gov.rw/eb/bav/selectListAdvertisingListForGU.do').content

# %%
umucyo_soup = BeautifulSoup(umucyo_web_page,'html.parser')
table = umucyo_soup.find_all("table", class_="article_table mb10")
th = table[0].find_all("thead")[0].find("tr").find_all("th")
th

# %%
trs = table[0].find("tbody").find_all("tr")
td = trs[0].find_all("td")
print(len(td))
print(len(th))
print(td)

# %%
for i in th:
  print(i.text)

# %%
columnsa = []

for i in th:
  regla = re.findall(r"[a-zA-Z0-9 ]+", i.text)
  for cols in regla:

    columnsa.append(cols)

print(columnsa)

df_umucyo = pd.DataFrame(columns=columnsa)
df_umucyo

# %%
later_rows= []
trs = table[0].find_all("tbody")[0].find_all("tr")

for td in trs:
  td_content = td.find_all("td")
  single_row=[]
  for td_t in td_content[1:]:
    f_data = td_t.text.strip()
    single_row.append(f_data)

  later_rows.append(single_row)
 

later_rows

# %%
df_umucyo1=pd.DataFrame(later_rows,columns=columnsa)
df_umucyo1

# %% [markdown]
# # Function to get job adverts in more than 50+

# %%
# !pip install easynmt

# %%
from easynmt import EasyNMT
#model = EasyNMT('opus-mt')
#model = EasyNMT('opus-mt', max_loaded_models=10)
model = EasyNMT('mbart50_en2m')


def adv_translate(language_t):

  this_arr=[]

  df_translated1 = pd.DataFrame()
  for transl_col in ['job_title', 'company_name','job_experience','published_date','job_deadline','Company_Profile','company_description', 'job_summary']:
    

    for index2, row2 in enumerate(df_result[transl_col]):
    
      Translations = model.translate(row2,target_lang=f'{language_t}') 
      df_result[transl_col][index2]=Translations
      this_arr.append(Translations)
      df4=df_result.iloc[index2:index2+1,:]
      df_translated=pd.concat([df_translated,df4])
  return df_translated1

# %% [markdown]
# # Fast API

# %%
# !pip install fastapi pyngrok unicorn nest-asyncio

# %%
# !pip install uvicorn

# %%
# !ngrok authtoken 2HJPnhvlBWISNubtEkRsF33F1JR_7srEdMeL114tfLGMQ7awh

# %%
# !pip install easynmt

# %%
df_result[['job_title','job_summary']]

# %%
from fastapi import FastAPI, Request
from datetime import datetime
#importing easy nmt
from easynmt import EasyNMT
from fastapi.responses import HTMLResponse

#defining our model or startying the model instance

model = EasyNMT("opus-mt")

storage = FastAPI(title='My FastAPI')

#df_jobs.to_dict('r')#IT
#df_umucyo1.to_dict('r')
#df_result.to_dict('r')#all jobs
#trans = adv_translate().to_dict('r')# to translate for you

#  fast API way
@storage.get('/', response_class=HTMLResponse)
def index():
    return f"""<html>
  <h1>Here is the first page: please Pay attention to details</h1><br><br>
   <p> fill with the corresponding urls to see:
  <h3>IT Jobs</h3>: <p>/it-jobs</p><br><br>
  <h3>All jobs</h3>: <p>/jobinrwanda-job-data</p><br><br>
  <h3>Umucyo Tenders</h3>: <p>/umucyo-tenders</p><br><br>
  <h3>to trnslate in your own language</h3>: <p></p>translate<br><br>
  
  </html>
  """
#==========================================================================================
@storage.get('/translated-dataFrame')
def translated_data_frame(category: str = None,job_title:str = None):

  if category:

    return df_jobs[['job_title','job_summary','published_date','job_deadline']].to_dict('r') 
  elif job_title:
    return df_jobs[['job_title','published_date','job_deadline']].to_dict('r')

  else:
    return df_translated.to_dict('r')
#=========================================================================================
#=========================================================================================
@storage.get('/umucyo-tenders')
def show_it_job_data(category: str = None,job_title:str = None):
  if category:
    return df_umucyo1[['Tender Name','Tender No','Deadline of Submitting']].to_dict('r') 
  elif job_title:
    return df_umucyo1[['Tender Name','Deadline of Submitting']].to_dict('r')

  else:
    return df_umucyo1.to_dict('r')
#=========================================================================================

#=======================================================================================
@storage.get('/it-jobs')
def show_it_job_data(category: str = None,job_title:str = None):
  if category:
    return df_jobs[['job_title','job_summary','published_date','job_deadline']].to_dict('r') 
  elif job_title:
    return df_jobs[['job_title','published_date','job_deadline']].to_dict('r')

  else:
    return df_jobs.to_dict('r')
#=========================================================================================
@storage.get('/translation')
def translate(text: str="",language_t: str=""):
  response = adv_translate(language_t).to_dict('r')
  return response

#============================================================================================

@storage.get('/jobinrwanda-job-data')
def show_job_data(category: str = None,job_title:str = None):
  if category:
    return df_result[['job_title','job_summary','published_date','job_deadline']].to_dict('r') 
  elif job_title:
    return df_result[['job_title','published_date','job_deadline']].to_dict('r')

  else:
    return df_result.to_dict('r')

#============================================================================================

# %%
import nest_asyncio
from pyngrok import ngrok
import uvicorn

ngrok_tunnel = ngrok.connect(8000)
print("REST API started")
print("Your public API URL:", ngrok_tunnel.public_url)
print("You can for example open the following URL in your browser: {}?target_lang=en&text=Hallo%20Welt".format(ngrok_tunnel.public_url))

nest_asyncio.apply()
uvicorn.run(storage, port=8000)

# %%
columns=[ 'job_title','company_name','job_link','company_link','job_category','job_experience','published_date','job_deadline','Company_Profile','company_description','job_summary']
